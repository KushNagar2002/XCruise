# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/KushNagar2002/XCruise/refs/heads/main/test.csv')

# %%
df
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso        25.0
# 1   Monday       Latte        15.0
# 2  Tuesday    Espresso         NaN
# 3  Tuesday       Latte        20.0

# %%
import numpy as np
df = df.replace({np.nan:None})

df
# Out:
#        Day Coffee Type Units Sold
# 0   Monday    Espresso       25.0
# 1   Monday       Latte       15.0
# 2  Tuesday    Espresso       None
# 3  Tuesday       Latte       20.0
